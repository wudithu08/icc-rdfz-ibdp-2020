# %% [markdown]
# 4/16/2019
#
# # Review
#
# Primary Storage
# - RAM
# - ROM
#
# 开机
# - 开机程序在ROM中
# - 开机过程 将必要程序读取到RAM中
#
# Cache
# - Spending up the system
# - between RAM & CPU
#     - Since RAM is too slow comparing to CPU
#
# Persistent storage
# - permanent data storage
#
# Function of OS
# - security
# - multi-tasking
# - intruption
# - user interface
# - resource management
# - ...
#
# Application software
# - Include
#     - word processor
#     - spreadsheets
#     - database management system (Dolby Access)
#     - email
#     - web browser
#     - computer aided design (CAD)
#     - graphic processing software
# - some feature is provided by the application software and some is provided by OS
#
# Store in computer
# - text
#     - ASCII
#         - 1 byte 1 character 4 bit
#     - Unicode
#         - 4 byte 1 character 32 bit
# - color
#     - RGB 3 byte
#     - usually in hex
#
# Logical Gate
# - AND/OR/NOT
# - NAND/NOR/XOR
#
# # Chapter 6
#
# Resourse need management
# - primary memory
# - secondary storage
# - processor speed
# - bandwidth
# - screen resolution
# - disk storage
# - sound processor
# - graphics processor
# - cache
# - network connetivity
#
# Role of OS
# - allocate resourse and *KEEPING TRACK* of program in memory
# - swapping between programs on time-slicing
#
# dedicated operating system for a device
# - Advantages related to size, speed and customization
# - e.g.a dedicated operating system for a cell phone rather than using a pre-existing operating system.
#     - different devices have different amount of resourse
#
# operating system hides the complexity of the hardware
# - virtualize real devices
#     - virtualize real devices, such as drive letters, virtual memory, input devices, the Java virtual machine.
# - abstraction lead to simplicity
#     - user cannot see changes in the hardware
#     - e.g. hard disks, floppy disks, CD-ROMs, and USB keys are very different media, but in many OSes they appear the same
